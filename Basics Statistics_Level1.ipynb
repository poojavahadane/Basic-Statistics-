# %%
import numpy as np
import pandas as pd
import math 
import statistics

# %% [markdown]
# ## Q7

# %%
data=pd.read_csv("Q7.csv")

# %%
data.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
data.mean()
# Out:
# C:\Users\cpakh\AppData\Local\Temp\ipykernel_2648\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\cpakh\AppData\Local\Temp\ipykernel_2648\4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
statistics.stdev(data.iloc[:,1])
# Out:
# 0.5346787360709715

# %%
statistics.stdev(data.iloc[:,2])
# Out:
# 0.9784574429896967

# %%
statistics.stdev(data.iloc[:,3])
# Out:
# 1.786943236096843

# %%
data.iloc[:,1:].mode()
# Out:
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90

# %%
statistics.variance(data["Points"])
# Out:
# 0.2858813508064516

# %%
statistics.variance(data["Score"])
# Out:
# 0.9573789677419355

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(data["Points"])
# Out:
# (array([3., 8., 2., 2., 4., 6., 5., 1., 0., 1.]),
#  array([2.76 , 2.977, 3.194, 3.411, 3.628, 3.845, 4.062, 4.279, 4.496,
#         4.713, 4.93 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.pairplot(data,kind="kde")

# %% [markdown]
# ## Q8

# %%
q_8=[108, 110, 123, 134, 135, 145, 167, 187, 199]
np.mean(q_8)
# Out:
# 145.33333333333334

# %% [markdown]
# ## Q9

# %%
data9a=pd.read_csv("Q9_a.csv")

# %%
data9a.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
from scipy.stats import skew,kurtosis

# %%
sns.pairplot(data9a,kind="kde")

# %%
print(skew(data9a.iloc[:,1:]))
print(kurtosis(data9a.iloc[:,1:]))
# Out:
# [-0.11395477  0.78248352]
# [-0.57714742  0.24801866]

# %%
data9b=pd.read_csv("Q9_b.csv")

# %%
data9b.head()
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149

# %%
sns.pairplot(data9b,kind="kde")

# %%
print(skew(data9b.iloc[:,1:]))
print(kurtosis(data9b.iloc[:,1:]))
# Out:
# [ 1.58145368 -0.60330993]
# [2.72352149 0.81946588]

# %%
import scipy.stats as st

# %% [markdown]
# ## Q11

# %%
st.t.interval(alpha=0.96, df=2000, loc=200, scale=30)
# Out:
# (138.34732124381935, 261.65267875618065)

# %%
st.t.interval(alpha=0.94, df=2000, loc=200, scale=30)
# Out:
# (143.54417173267188, 256.4558282673281)

# %%
st.t.interval(alpha=0.98, df=2000, loc=200, scale=30)
# Out:
# (130.1535847418068, 269.8464152581932)

# %% [markdown]
# ## Q12

# %%
a=[34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]
np.mean(a)
# Out:
# 41.0

# %%
np.median(a)
# Out:
# 40.5

# %%
statistics.variance(a)
# Out:
# 25.529411764705884

# %%
statistics.stdev(a)
# Out:
# 5.05266382858645

# %% [markdown]
# ## Q20

# %%
data20=pd.read_csv("Cars.csv")

# %%
data20.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
data20.shape
# Out:
# (81, 5)

# %%
len(data20[data20["MPG"]>38])/len(data20["MPG"])
# Out:
# 0.4074074074074074

# %%
len(data20[data20["MPG"]<40])/len(data20["MPG"])
# Out:
# 0.7530864197530864

# %%
1-((len(data20[data20["MPG"]<20])+len(data20[data20["MPG"]>50]))/len(data20["MPG"]))
# Out:
# 0.8518518518518519

# %% [markdown]
# ## Q21

# %%
data21=data20.copy()

# %%
sns.pairplot(data21,kind="kde")

# %% [markdown]
# ## Q21b

# %%
data21=pd.read_csv("wc-at.csv")

# %%
data21.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
data21.shape
# Out:
# (109, 2)

# %%
sns.pairplot(data21,kind="kde")

# %% [markdown]
# ## Q22

# %%
st.norm.ppf(.90)
# Out:
# 1.2815515655446004

# %%
st.norm.ppf(.94)
# Out:
# 1.5547735945968535

# %%
st.norm.ppf(.60)
# Out:
# 0.2533471031357997

# %% [markdown]
# ## Q23

# %%
st.t.ppf(0.95,df=25)
# Out:
# 1.7081407612518986

# %%
st.t.ppf(0.96,df=25)
# Out:
# 1.8248284689556018

# %%
st.t.ppf(0.99,df=25)
# Out:
# 2.4851071754106413

# %% [markdown]
# ## Q24

# %%
t=(260-270)/(90/(18**0.5))

# %%
t
# Out:
# -0.4714045207910317

# %%
st.t.sf(abs(t), df=17)
# Out:
# 0.32167253567098364
